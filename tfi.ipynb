# %%
import cv2
import pytesseract
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

print("OpenCV version:", cv2.__version__)
# Out:
# OpenCV version: 4.11.0

# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt

i1 = cv2.imread("test.jpg")
i1_rgb = cv2.cvtColor(i1, cv2.COLOR_BGR2RGB)
plt.imshow(i1_rgb)
plt.axis('off')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("test.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
plt.imshow(thresh, cmap='gray')
plt.title("Thresholded Image")
plt.axis('off')
plt.show()

# %%
import pytesseract
import shutil
import os


tesseract_path = shutil.which("tesseract")

if tesseract_path:
    print(f"Tesseract found at: {tesseract_path}")
else:
    default_path = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
    if os.path.exists(default_path):
        pytesseract.pytesseract.tesseract_cmd = default_path
        print(f"Tesseract found at default path: {default_path}")
    else:
        print("Tesseract not found. Please install it.")
        raise FileNotFoundError("Tesseract OCR is not installed or not found in PATH.")

print("Tesseract version:", pytesseract.get_tesseract_version())
# Out:
# Tesseract found at default path: C:\Program Files\Tesseract-OCR\tesseract.exe
# Tesseract version: 5.5.0.20241111

# %%
import pytesseract

text = pytesseract.image_to_string(thresh)
print("Extracted Text:\n")
print(text)



data = pytesseract.image_to_data(thresh)
print("\nFirst 200 chars of data:\n")
print(data[:200])
# Out:
# Extracted Text:
#
# Text extraction
#
# Full text indexing of file
# contents based on various
# parser libraries (POT,
# PDFBox, etc.).
#
# Currently only for the
# jcr:data property with
# correct jcr:mime Type.
#
# Jackrabbit 2.0: indexing of
# all binary properties.
#
# textFilterClasses:
# PlainTextExtractor
# MsWordTextExtractor
# MsExcelTextExtractor
# MsPowerPoint TextExtractor
# Pdf TextExtractor
# OpenOfficeTextExtractor
# RTFTextExtractor
#
# HTML TextExtractor
# XMLTextExtractor
#
#
#
# First 200 chars of data:
#
# level	page_num	block_num	par_num	line_num	word_num	left	top	width	height	conf	text
# 1	1	0	0	0	0	0	0	1024	768	-1
# 2	1	1	0	0	0	28	41	407	43	-1
# 3	1	1	1	0	0	28	41	407	43	-1
# 4	1	1	1	1	0	28	41	407	43	-1
# 5
